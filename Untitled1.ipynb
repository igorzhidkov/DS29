# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline
import sklearn

# %%
from sklearn import datasets
diabetes = datasets.load_diabetes()

# %%
df=pd.DataFrame(diabetes.data)
df.columns= diabetes.feature_names
# Creating a new column containing response variable 'y' (a quantitative measure of disease progressionone year after baseline)
df['diabetes_measure']=diabetes.target
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  diabetes_measure
# 0 -0.002592  0.019908 -0.017646             151.0
# 1 -0.039493 -0.068330 -0.092204              75.0
# 2 -0.002592  0.002864 -0.025930             141.0
# 3  0.034309  0.022692 -0.009362             206.0
# 4 -0.002592 -0.031991 -0.046641             135.0

# %%
# Creating the feature matrix X
X=df.iloc[:,:-1]
# Creating the response vector y
y=df.iloc[:,-1]
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019908 -0.017646
# 1   -0.039493 -0.068330 -0.092204
# 2   -0.002592  0.002864 -0.025930
# 3    0.034309  0.022692 -0.009362
# 4   -0.002592 -0.031991 -0.046641
# ..        ...       ...       ...
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018118  0.044485
# 439 -0.011080 -0.046879  0.015491
# 440  0.026560  0.044528 -0.025930
# 441 -0.039493 -0.004220  0.003064
#
# [442 rows x 10 columns]

# %%
# Choosing 'bmi' as the only feature from the feature matrix X and reshaping the array to 2 dimensions
bmi = X.iloc[:,2]
bmi=bmi[:,np.newaxis]
# Choosing 'diabetes_measure' as the response variable and reshaping the array to 2 dimensions
y= df.iloc[:,-1]
y=y[:,np.newaxis]
# Out:
# <ipython-input-14-5481c52281a2>:3: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   bmi=bmi[:,np.newaxis]
# <ipython-input-14-5481c52281a2>:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y=y[:,np.newaxis]

# %%
# importing the LinearRegression class from linear_model submodule of scikit learn
from sklearn.linear_model import LinearRegression
# instantiating
simple_lr = LinearRegression()
# Fitting the simple_lr object to the data
simple_lr = LinearRegression().fit(bmi,y)
# predicting the response values and saving them in an object called predicted_y
predicted_y = simple_lr.predict(bmi)
# predicted_y

# %%
simple_lr.score(bmi, y)
# Out:
# 0.3439237602253803

# %%
# plotting the regression line on the scatter plot
plt.figure(figsize=(10,6))
plt.scatter(bmi, y)
plt.plot(bmi, predicted_y, c='r')
plt.title('Scatter plot and a Simple Linear Regression Model')
plt.ylabel("y")
plt.xlabel("bmi")
plt.show()

# %%
# Importing cross_val_score function from the model_selection submodule of scikit learn
from sklearn.model_selection import cross_val_score
# storing the ten scores in an object called mse
mse= cross_val_score(simple_lr,bmi,y,scoring='neg_mean_squared_error',cv=10)
# taking the mean of mse for using as an indicator of how good the model is
mse.mean()
# Out:
# -3906.91899010684

# %%
# importing the LinearRegression class from linear_model submodule of scikit learn
from sklearn.linear_model import LinearRegression
# instantiating
multiple_lr = LinearRegression()
# Fitting the multiple_lr object to the data , this time using the whole feature matrix X
multiple_lr = LinearRegression().fit(X,y)
# Importing cross_val_score function from the model_selection submodule of scikit learn
from sklearn.model_selection import cross_val_score
# storing the ten scores in an object called mse
mse= cross_val_score(multiple_lr,X,y,scoring='neg_mean_squared_error',cv=10)
# taking the mean of mse for using as an indicator of how good the model is
mse.mean()
# Out:
# -3000.3810328390514

# %%
# Saving an array containing all the ten coefficients
multiple_lr_coeffs = multiple_lr.coef_[0]
multiple_lr_coeffs
# Out:
# array([ -10.01219782, -239.81908937,  519.83978679,  324.39042769,
#        -792.18416163,  476.74583782,  101.04457032,  177.06417623,
#         751.27932109,   67.62538639])

# %%
# fetching feature names from the dataframe df
feature_names = df.drop('diabetes_measure',axis=1).columns
feature_names
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
# Using matplotlib commands to plot
plt.figure(figsize=(10,6))
plt.plot(range(len(multiple_lr_coeffs)),multiple_lr_coeffs)
plt.axhline(0, color='r', linestyle='solid')
plt.xticks(range(len(feature_names)),feature_names,rotation=50)
plt.title("Coefficients for Multiple Linear Regression")
plt.ylabel("coefficients")
plt.xlabel("features")
plt.show()

# %%
X.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_5178e5c5_5dd5_11ec_ac10_68f728f15909row0_col0,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row1_col1,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row2_col2,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row3_col3,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row4_col4,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row5_col5,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row6_col6,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row7_col7,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row8_col8,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row9_col9{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row0_col1{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row0_col2{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row0_col3{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row0_col4,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row1_col0{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row0_col5{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row0_col6,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row2_col5,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row3_col0{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row0_col7,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row7_col9{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row0_col8{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row0_col9,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row3_col1,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row4_col2{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row1_col2{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row1_col3,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row4_col3{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row1_col4,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row6_col0,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row6_col1,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row6_col2,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row6_col3,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row6_col5,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row6_col7,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row6_col8,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row6_col9,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row7_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row1_col5{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row1_col6{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row1_col7{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row1_col8{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row1_col9,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row5_col1{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row2_col0{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row2_col1{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row2_col3,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row8_col3{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row2_col4{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row2_col6,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row3_col4{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row2_col7{
#             background-color:  #f7b99e;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row2_col8{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row2_col9,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row3_col9{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row3_col2{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row3_col5{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row3_col6,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row8_col0{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row3_col7,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row7_col2{
#             background-color:  #edd1c2;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row3_col8{
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row4_col0,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row5_col3,#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row5_col6{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row4_col1{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row4_col5{
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row4_col6{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row4_col7{
#             background-color:  #f59f80;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row4_col8{
#             background-color:  #f7bca1;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row4_col9{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row5_col0{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row5_col2{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row5_col4{
#             background-color:  #d85646;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row5_col7{
#             background-color:  #ed8366;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row5_col8{
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row5_col9{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row6_col4{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row7_col0{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row7_col1{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row7_col3{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row7_col4{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_5178e5c5_5dd5_11ec_ac10_68f728f15909row7_col5{
#             background-color:  #f7a
